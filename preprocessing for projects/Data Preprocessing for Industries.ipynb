# %%
# import necessary packages
import pandas as pd
import numpy as np
from sklearn import preprocessing
import statsmodels.api as sm
from sklearn import linear_model

# %%
import os
os.chdir('/Users/asudomoeva/Desktop/Capstone')

# %% [markdown]
# # Working with industry data

# %%
industry_target = pd.read_csv('Data and Preprocessing/Data/industry_target from sba.csv')
industry_data = pd.read_csv('Data and Preprocessing/Data/industry_allyear.csv')
industry_index = pd.read_csv('Data and Preprocessing/Data/Codes.csv')
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (10,19,20,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Let's start with mapping targets from SBA

# %%
# reading in the index file
industry_index = industry_index.rename(index=str, columns={"2017 NAICS US   Code": "NAICS"})
industry_index['NAICS'] = pd.to_numeric(industry_index['NAICS'])

# %%
industry_target=industry_target.merge(industry_index, on='NAICS', how='left')

# %%
# filtering for those firms of size less than 500 employees 
ind_state_target = industry_target.loc[industry_target['firm type'].isin(['firm', 'firms'])][['Year', 
                                                        'State', 'NAICS', '<500', '2017 NAICS US Title']]
ind_state_target['<500'] = pd.to_numeric(ind_state_target['<500'])
ind_state_target['Year'] = ind_state_target['Year'].astype(int)

# %%
# create one for the US
ind_us_target = ind_state_target.groupby(['NAICS', 'Year']).sum()

# %%
ind_state_target.head()
# Out:
#    Year    State  NAICS   <500  \
# 0  2011  Alabama    113  586.0
# 1  2011  Alabama    114   22.0
# 2  2011  Alabama    115  163.0
# 3  2011  Alabama    211   18.0
# 4  2011  Alabama    212   78.0
#
#                                2017 NAICS US Title
# 0                             Forestry and Logging
# 1                    Fishing, Hunting and Trapping
# 2  Support Activities for Agriculture and Forestry
# 3                           Oil and Gas Extraction
# 4                      Mining (except Oil and Gas)

# %%
ind_us_target.head()
# Out:
#                <500
# NAICS Year
# 113   1998  13982.0
#       1999  13444.0
#       2000  13099.0
#       2001  12561.0
#       2002  12274.0

# %% [markdown]
# ## Now we can take a look at the data from CENSUS
#
# The feature description table:

# %% [markdown]
# |  Name | Type   |  Description |
# |---|---|---|
# |  STATE | 	C   | Geographic Area Code, FIPS State 2-digit codes  |
# | NAICS  |  C   |  Industry Code; 6-digit, North American Industry Classification System (NAICS) |
# |  ENTRSIZE |  C  |  Enterprise Employment Size Code |
# |  INIT_ESTB |  N  |  Number of Initial Year Establishments |
# |  INIT_EMPL |  N  | Initial Year Employment with Noise  |
# |  INIT_EMPLFL_N |  C  | Initial Year Employment Noise Flag   |
# | INIT_EMPFL_R  | C   |   Initial Year Employment Range Flag / Data Suppression Flag |
# |  NETCHG_ESTB |  N |  Change in Establishments |
# | NETCHG_EMPL   |  N |  Change in Employment |
# |  NETCHG_EMPLFL_N  | C  | Net Change Noise Flag (G,H,D,S... see INIT_EMPLFL_N)  |
# |  BIRTHS_ESTB  | N   |  Number of Establishment Births  |
# |  BIRTHS_EMPL  |  N  |  Establishment Births Employment with Noise  |
# |   BIRTHS_EMPLFL_N|  C   |  Establishment Births Noise Flag (G,H,D,S... see INIT_EMPLFL_N  |
# |  DEATHS_ESTB  |  N   |  Number of Establishment Deaths  |
# |  DEATHS_EMPL   |   N  |  Establishment Deaths Employment with Noise  |
# |  DEATHS_EMPLFL_N  |  C   |  Establishment Deaths Noise Flag (G,H,D,S... see INIT_EMPLFL_N)  |
# |   EXP_ESTB |  N   |  Number of Establishment Expansions  |
# |   EXP_EMPL |  N   |   Establishment Expansions Change in Employment with Noise |
# |  EXP_EMPLFL_N  |  C   |  Establishment Expansion Noise Flag  |
# |  CONTR_ESTB  |   N  |  Number of Establishment Contractions  |
# |  CONTR_EMPL  |   N |  Establishment Contractions Change in Employment with Noise  |
# |  CONTR_EMPLFL_N  |   C  | Establish Contractors Noise Flag   |
# |   PCTCHG_ESTB |  N   |  Percent Change Establishments  |
# |  PCTCHG_EMPL  |  N  |   Percent Change in Employment |
# |  PCTCHG_BIRTHS_EMPL  |  N   |  Percent Change in Employment Due to Births  |
# |  PCTCHG_DEATHS_EMPL  |  N   |   Percent Change in Employment Due to Deaths |
# |  PCTCHG_BIRTHS_EXP_EMPL  |  N   |   Percent Change in Employment Due to Births & Expansion |
# |  PCTCGH_DEATHS_CONTR_EMPL  | N   | Percent change in Employment Due to Deaths & Contractions    |
# |  STATEDSCR  |  C   |  State Description  |
# |  NAICSDSCR  |   C  |  NAICS Industry Description  |
# |  ENTRSIZEDSCR  |  C   |  Enterprise Employment Size Description  |

# %% [markdown]
# This denotes employment size class for data withheld to avoid disclosure (confidentiality) or withheld because data do not meet publication standards.
#
# 1. A:        0-19
# 2. B:        20-99
# 3. C:        100-249
# 4. E:        250-499
# 5. F:        500-999
# 6. G:        1,000-2,499
# 7. H:        2,500-4,999
# 8. I:        5,000-9,999
# 9. J:        10,000-24,999
# 10. K:        25,000-49,999
# 11. L:        50,000-99,999
# 12. M:        100,000 or More
#
# _____________________
# Other marks
# 1. G:        Low noise applied to cell value (0 to < 2%)
# 2. H:        Medium noise applied to cell value (2 to < 5%)
# 3. D:        Data withheld and value set to 0 to avoid disclosing data for individual businesses; data are included in higher level totals.
# 4. S:       Data withheld and value set to 0 to avoise releasing information that does not meet publication standards; data are included in higher level totals.

# %% [markdown]
# Will be treating as targets:
# 1. Number of Initial Year Establishments
# 2. Change in Establishments
# 3. Number of Establishment Births
# 4. Number of Establishment Deaths
# 5. Number of Establishment Expansions
# 6. Number of Establishment Contractions
# 7. Percent Change Establishments

# %%
# split the US data with States and using '7' to filter for industries with less than 500 employees
industry_us_data = industry_data.loc[(industry_data['STATE'] == 0) & (industry_data['ENTRSIZE'] == 7)][['NAICS',
                                                    'INIT_ESTB', 'NETCHG_ESTB', 'BIRTHS_ESTB', 'DEATHS_ESTB', 
                                                'EXP_ESTB', 'CONTR_ESTB', 'PCTCHG_ESTB','NCSDSCR','year' ]]
industry_state_data = industry_data.loc[(industry_data['STATE'] != 0) & (industry_data['ENTRSIZE'] == 7)][['STATE',
                                                 'NAICS', 'INIT_ESTB', 'NETCHG_ESTB', 'BIRTHS_ESTB', 'DEATHS_ESTB', 
                                             'EXP_ESTB', 'CONTR_ESTB', 'PCTCHG_ESTB','NCSDSCR','year', 'STATEDSCR']]

# %%
industry_us_data.head(3)
# Out:
#    NAICS  INIT_ESTB  NETCHG_ESTB  BIRTHS_ESTB  DEATHS_ESTB  EXP_ESTB  \
# 6     --    5775217       -47102       625873       672975   1462447
# 14    11      19350         -662         2096         2758      4230
# 22   113       9183         -551          760         1311      2069
#
#     CONTR_ESTB  PCTCHG_ESTB NCSDSCR  year
# 6      1505943         -0.8     NaN  2008
# 14        4751         -3.4     NaN  2008
# 22        2617         -6.0     NaN  2008

# %%
industry_state_data.head(3)
# Out:
#       STATE NAICS  INIT_ESTB  NETCHG_ESTB  BIRTHS_ESTB  DEATHS_ESTB  EXP_ESTB  \
# 3218      1    --      78993         -861         7720         8581     20604
# 3226      1    11        845          -34           55           89       198
# 3234      1    21        157           -4           13           17        47
#
#       CONTR_ESTB  PCTCHG_ESTB NCSDSCR  year STATEDSCR
# 3218       21860         -1.1     NaN  2008   Alabama
# 3226         265         -4.0     NaN  2008   Alabama
# 3234          58         -2.5     NaN  2008   Alabama

# %% [markdown]
# _________

# %% [markdown]
# # Adding the industry targets and description into our final dataset

# %% [markdown]
# ## First let's take a look at states full dataset

# %%
# create a 1:1 match between a state and a top industry to add into the bigger state regression
state_industry = pd.read_csv('Data and Preprocessing/Data/State to Industry Mapping.csv')
temp_data = pd.read_csv('Data and Preprocessing/Data/final_data(industry not added).csv')
temp_data = temp_data.replace({'(NA)': None, '(L)': 75000})
temp_data = temp_data.drop(['Compensation of employees', 'Gross operating surplus', 'Per capita real GDP by state',
                           'Subsidies', 'Taxes on production and imports', 
                            'Taxes on production and imports less subsidies', 'Forest and maple products'], axis=1)
final_data = temp_data.merge(state_industry, on='state', how='left')
final_data['GDP PC'] = temp_data['Real GDP by state']/temp_data['Population (persons) ']
final_data = final_data.dropna()
final_data['NAICS'] = final_data['NAICS'].astype(int)

# %%
# turning top industry into dummies
industry_dummies = pd.get_dummies(final_data['Top Industry'])
final_data = pd.concat([final_data, industry_dummies], axis=1, sort=False)

# %%
# outputting final data for states
final_data.to_csv('final_data_states.csv')

# %% [markdown]
# ## Merging datatsets for indsutry target and states data

# %% [markdown]
# ## Just industry data

# %%
# need more industry indicators

# %%
# output the final file

# %% [markdown]
# ## Industry-State Data

# %%
final_data_sub = final_data[final_data.columns[:-16]]

# %%
final_data_sub['unique_name'] = final_data_sub['year'].astype(str) + '_' + final_data_sub[
    'GeoName']
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
industry_state_data['unique_name'] = industry_state_data['year'].astype(str) + '_' + industry_state_data[
    'STATEDSCR'].astype(str)
industry_state_data = industry_state_data.loc[industry_state_data['NAICS'] != '--']

# %%
industry_descriptions = industry_state_data['NCSDSCR']
industry_state_data = industry_state_data.drop(['NCSDSCR'], axis=1)
industry_state_data = industry_state_data.merge(final_data_sub, on='unique_name', how='left')

# %% [markdown]
# ### Working with NAICS codes
# 1. 31-33 - turning into 31 for usability (will need to check for 32 and 33 when merging)
# 2. 44-45 - turning into 44
# 3. 48-49 - turning into 48

# %%
industry_state_data['NAICS_x'] = industry_state_data['NAICS_x'].replace({'31-33': 31, '44-45': 44, '48-49':48})

# %%
#trimming NAICS_y (top industry in the state)
industry_state_data['NAICS_y'] = industry_state_data['NAICS_y'].apply(lambda x: str(x)[:2])

# %%
industry_state_data = industry_state_data.replace({'na': None}).dropna()

# %%
industry_state_data['top_industry_bool'] = (pd.to_numeric(industry_state_data[
            'NAICS_x']) == pd.to_numeric(industry_state_data['NAICS_y'])).astype(int)

# %%
industry_state_data
# Out:
#       STATE NAICS_x  INIT_ESTB  NETCHG_ESTB  BIRTHS_ESTB  DEATHS_ESTB  \
# 0         1      11        845          -34           55           89
# 1         1      21        157           -4           13           17
# 2         1      22        118           -2            1            3
# 3         1      23       9151         -335         1032         1367
# 4         1      31       3843          -10          279          289
# 5         1      42       4356          -57          281          338
# 6         1      44      12643         -347         1190         1537
# 7         1      48       2398          -98          279          377
# 8         1      51        754          -24           57           81
# 9         1      52       4024            4          327          323
# 10        1      53       3198           48          465          417
# 11        1      54       7984           80          863          783
# 12        1      55        277           -8           13           21
# 13        1      56       3146          -20          412          432
# 14        1      61        715           11           81           70
# 15        1      62       8628           26          594          568
# 16        1      71        936            4          111          107
# 17        1      72       5515           10          831          821
# 18        1      81      10265         -122          787          909
# 19        1      99         40           17           49           32
# 20        2      11        165          -24           23           47
# 21        2      21         61            6           11            5
# 22        2      22         82            1            2            1
# 23        2      23       1986          -46          332          378
# 24        2      31        370           13           49           36
# 25        2      42        459          -11           24           35
# 26        2      44       1945          -52          165          217
# 27        2      48        683          -12           68           80
# 28        2      51        210            9           22           13
# 29        2      52        421          -11           35           46
# ...     ...     ...        ...          ...          ...          ...
# 8129     55      53       3497           48          355          307
# 8130     55      54       9307           47          824          777
# 8131     55      55        431           15           33           18
# 8132     55      56       4558          110          594          484
# 8133     55      61       1323           49          130           81
# 8134     55      62      11057           85          844          759
# 8135     55      71       2107           22          204          182
# 8136     55      72      11135           16         1021         1005
# 8137     55      81      13134           27          773          746
# 8138     55      99        158           55          114           59
# 8139     56      11         63           -4            8           12
# 8140     56      21        586          -10           54           64
# 8141     56      22         47            3            4            1
# 8142     56      23       2186           55          282          227
# 8143     56      31        441           11           48           37
# 8144     56      42        549          -13           23           36
# 8145     56      44       1849            1          131          130
# 8146     56      48        693            1           88           87
# 8147     56      51        214            1           18           17
# 8148     56      52        655           30           68           38
# 8149     56      53        846           41          114           73
# 8150     56      54       1808           51          242          191
# 8151     56      55         41            7            8            1
# 8152     56      56        710           19          100           81
# 8153     56      61        143           14           26           12
# 8154     56      62       1660           36          130           94
# 8155     56      71        305            5           34           29
# 8156     56      72       1472           17          149          132
# 8157     56      81       1591           13          126          113
# 8158     56      99         32           14           25           11
#
#       EXP_ESTB  CONTR_ESTB  PCTCHG_ESTB  year_x        ...          \
# 0          198         265         -4.0    2008        ...
# 1           47          58         -2.5    2008        ...
# 2           31          22         -1.7    2008        ...
# 3         2229        2983         -3.7    2008        ...
# 4         1218        1379         -0.3    2008        ...
# 5         1198        1125         -1.3    2008        ...
# 6         3152        3587         -2.7    2008        ...
# 7          551         678         -4.1    2008        ...
# 8          207         176         -3.2    2008        ...
# 9          931         788          0.1    2008        ...
# 10         639         715          1.5    2008        ...
# 11        1863        1834          1.0    2008        ...
# 12          81          82         -2.9    2008        ...
# 13         913         862         -0.6    2008        ...
# 14         227         215          1.5    2008        ...
# 15        2713        2204          0.3    2008        ...
# 16         270         293          0.4    2008        ...
# 17        1676        1944          0.2    2008        ...
# 18        2459        2648         -1.2    2008        ...
# 19           1           2         42.5    2008        ...
# 20          23          14        -14.5    2008        ...
# 21          17          25          9.8    2008        ...
# 22          21          22          1.2    2008        ...
# 23         542         594         -2.3    2008        ...
# 24         107         111          3.5    2008        ...
# 25         145         131         -2.4    2008        ...
# 26         562         589         -2.7    2008        ...
# 27         242         149         -1.8    2008        ...
# 28          61          51          4.3    2008        ...
# 29         102          92         -2.6    2008        ...
# ...        ...         ...          ...     ...        ...
# 8129       748         598          1.4    2015        ...
# 8130      2098        1859          0.5    2015        ...
# 8131       136          93          3.5    2015        ...
# 8132      1360        1142          2.4    2015        ...
# 8133       480         380          3.7    2015        ...
# 8134      3133        2918          0.8    2015        ...
# 8135       651         571          1.0    2015        ...
# 8136      3934        3541          0.1    2015        ...
# 8137      3271        2922          0.2    2015        ...
# 8138        11           6         34.8    2015        ...
# 8139        11          12         -6.3    2015        ...
# 8140       117         169         -1.7    2015        ...
# 8141        11           2          6.4    2015        ...
# 8142       725         571          2.5    2015        ...
# 8143       135         131          2.5    2015        ...
# 8144       147         133         -2.4    2015        ...
# 8145       561         475          0.1    2015        ...
# 8146       184         170          0.1    2015        ...
# 8147        67          52          0.5    2015        ...
# 8148       152         104          4.6    2015        ...
# 8149       169         126          4.8    2015        ...
# 8150       353         318          2.8    2015        ...
# 8151         5          10         17.1    2015        ...
# 8152       180         167          2.7    2015        ...
# 8153        44          42          9.8    2015        ...
# 8154       439         414          2.2    2015        ...
# 8155        89          64          1.6    2015        ...
# 8156       552         486          1.2    2015        ...
# 8157       381         372          0.8    2015        ...
# 8158         9           3         43.8    2015        ...
#
#      contract_establish end_establish expand_establish  net_change  \
# 0              751202.0      128306.0         610200.0   -135240.0
# 1              751202.0      128306.0         610200.0   -135240.0
# 2              751202.0      128306.0         610200.0   -135240.0
# 3              751202.0      128306.0         610200.0   -135240.0
# 4              751202.0      128306.0         610200.0   -135240.0
# 5              751202.0      128306.0         610200.0   -135240.0
# 6              751202.0      128306.0         610200.0   -135240.0
# 7              751202.0      128306.0         610200.0   -135240.0
# 8              751202.0      128306.0         610200.0   -135240.0
# 9              751202.0      128306.0         610200.0   -135240.0
# 10             751202.0      128306.0         610200.0   -135240.0
# 11             751202.0      128306.0         610200.0   -135240.0
# 12             751202.0      128306.0         610200.0   -135240.0
# 13             751202.0      128306.0         610200.0   -135240.0
# 14             751202.0      128306.0         610200.0   -135240.0
# 15             751202.0      128306.0         610200.0   -135240.0
# 16             751202.0      128306.0         610200.0   -135240.0
# 17             751202.0      128306.0         610200.0   -135240.0
# 18             751202.0      128306.0         610200.0   -135240.0
# 19             751202.0      128306.0         610200.0   -135240.0
# 20             163548.0       35464.0         167616.0      6718.0
# 21             163548.0       35464.0         167616.0      6718.0
# 22             163548.0       35464.0         167616.0      6718.0
# 23             163548.0       35464.0         167616.0      6718.0
# 24             163548.0       35464.0         167616.0      6718.0
# 25             163548.0       35464.0         167616.0      6718.0
# 26             163548.0       35464.0         167616.0      6718.0
# 27             163548.0       35464.0         167616.0      6718.0
# 28             163548.0       35464.0         167616.0      6718.0
# 29             163548.0       35464.0         167616.0      6718.0
# ...                 ...           ...              ...         ...
# 8129           874128.0      144774.0         913672.0     77276.0
# 8130           874128.0      144774.0         913672.0     77276.0
# 8131           874128.0      144774.0         913672.0     77276.0
# 8132           874128.0      144774.0         913672.0     77276.0
# 8133           874128.0      144774.0         913672.0     77276.0
# 8134           874128.0      144774.0         913672.0     77276.0
# 8135           874128.0      144774.0         913672.0     77276.0
# 8136           874128.0      144774.0         913672.0     77276.0
# 8137           874128.0      144774.0         913672.0     77276.0
# 8138           874128.0      144774.0         913672.0     77276.0
# 8139           137100.0       28562.0         118766.0    -17780.0
# 8140           137100.0       28562.0         118766.0    -17780.0
# 8141           137100.0       28562.0         118766.0    -17780.0
# 8142           137100.0       28562.0         118766.0    -17780.0
# 8143           137100.0       28562.0         118766.0    -17780.0
# 8144           137100.0       28562.0         118766.0    -17780.0
# 8145           137100.0       28562.0         118766.0    -17780.0
# 8146           137100.0       28562.0         118766.0    -17780.0
# 8147           137100.0       28562.0         118766.0    -17780.0
# 8148           137100.0       28562.0         118766.0    -17780.0
# 8149           137100.0       28562.0         118766.0    -17780.0
# 8150           137100.0       28562.0         118766.0    -17780.0
# 8151           137100.0       28562.0         118766.0    -17780.0
# 8152           137100.0       28562.0         118766.0    -17780.0
# 8153           137100.0       28562.0         118766.0    -17780.0
# 8154           137100.0       28562.0         118766.0    -17780.0
# 8155           137100.0       28562.0         118766.0    -17780.0
# 8156           137100.0       28562.0         118766.0    -17780.0
# 8157           137100.0       28562.0         118766.0    -17780.0
# 8158           137100.0       28562.0         118766.0    -17780.0
#
#       open_establish  total_contract  total_expand  \
# 0           134068.0        879508.0      744268.0
# 1           134068.0        879508.0      744268.0
# 2           134068.0        879508.0      744268.0
# 3           134068.0        879508.0      744268.0
# 4           134068.0        879508.0      744268.0
# 5           134068.0        879508.0      744268.0
# 6           134068.0        879508.0      744268.0
# 7           134068.0        879508.0      744268.0
# 8           134068.0        879508.0      744268.0
# 9           134068.0        879508.0      744268.0
# 10          134068.0        879508.0      744268.0
# 11          134068.0        879508.0      744268.0
# 12          134068.0        879508.0      744268.0
# 13          134068.0        879508.0      744268.0
# 14          134068.0        879508.0      744268.0
# 15          134068.0        879508.0      744268.0
# 16          134068.0        879508.0      744268.0
# 17          134068.0        879508.0      744268.0
# 18          134068.0        879508.0      744268.0
# 19          134068.0        879508.0      744268.0
# 20           38114.0        199012.0      205730.0
# 21           38114.0        199012.0      205730.0
# 22           38114.0        199012.0      205730.0
# 23           38114.0        199012.0      205730.0
# 24           38114.0        199012.0      205730.0
# 25           38114.0        199012.0      205730.0
# 26           38114.0        199012.0      205730.0
# 27           38114.0        199012.0      205730.0
# 28           38114.0        199012.0      205730.0
# 29           38114.0        199012.0      205730.0
# ...              ...             ...           ...
# 8129        182506.0       1018902.0     1096178.0
# 8130        182506.0       1018902.0     1096178.0
# 8131        182506.0       1018902.0     1096178.0
# 8132        182506.0       1018902.0     1096178.0
# 8133        182506.0       1018902.0     1096178.0
# 8134        182506.0       1018902.0     1096178.0
# 8135        182506.0       1018902.0     1096178.0
# 8136        182506.0       1018902.0     1096178.0
# 8137        182506.0       1018902.0     1096178.0
# 8138        182506.0       1018902.0     1096178.0
# 8139         29116.0        165662.0      147882.0
# 8140         29116.0        165662.0      147882.0
# 8141         29116.0        165662.0      147882.0
# 8142         29116.0        165662.0      147882.0
# 8143         29116.0        165662.0      147882.0
# 8144         29116.0        165662.0      147882.0
# 8145         29116.0        165662.0      147882.0
# 8146         29116.0        165662.0      147882.0
# 8147         29116.0        165662.0      147882.0
# 8148         29116.0        165662.0      147882.0
# 8149         29116.0        165662.0      147882.0
# 8150         29116.0        165662.0      147882.0
# 8151         29116.0        165662.0      147882.0
# 8152         29116.0        165662.0      147882.0
# 8153         29116.0        165662.0      147882.0
# 8154         29116.0        165662.0      147882.0
# 8155         29116.0        165662.0      147882.0
# 8156         29116.0        165662.0      147882.0
# 8157         29116.0        165662.0      147882.0
# 8158         29116.0        165662.0      147882.0
#
#                                    Top Industry  NAICS_y  top_industry_bool
# 0               Ambulatory health care services       62                  0
# 1               Ambulatory health care services       62                  0
# 2               Ambulatory health care services       62                  0
# 3               Ambulatory health care services       62                  0
# 4               Ambulatory health care services       62                  0
# 5               Ambulatory health care services       62                  0
# 6               Ambulatory health care services       62                  0
# 7               Ambulatory health care services       62                  0
# 8               Ambulatory health care services       62                  0
# 9               Ambulatory health care services       62                  0
# 10              Ambulatory health care services       62                  0
# 11              Ambulatory health care services       62                  0
# 12              Ambulatory health care services       62                  0
# 13              Ambulatory health care services       62                  0
# 14              Ambulatory health care services       62                  0
# 15              Ambulatory health care services       62                  1
# 16              Ambulatory health care services       62                  0
# 17              Ambulatory health care services       62                  0
# 18              Ambulatory health care services       62                  0
# 19              Ambulatory health care services       62                  0
# 20                       Oil and gas extraction       21                  0
# 21                       Oil and gas extraction       21                  1
# 22                       Oil and gas extraction       21                  0
# 23                       Oil and gas extraction       21                  0
# 24                       Oil and gas extraction       21                  0
# 25                       Oil and gas extraction       21                  0
# 26                       Oil and gas extraction       21                  0
# 27                       Oil and gas extraction       21                  0
# 28                       Oil and gas extraction       21                  0
# 29                       Oil and gas extraction       21                  0
# ...                                         ...      ...                ...
# 8129  Insurance carriers and related activities       52                  0
# 8130  Insurance carriers and related activities       52                  0
# 8131  Insurance carriers and related activities       52                  0
# 8132  Insurance carriers and related activities       52                  0
# 8133  Insurance carriers and related activities       52                  0
# 8134  Insurance carriers and related activities       52                  0
# 8135  Insurance carriers and related activities       52                  0
# 8136  Insurance carriers and related activities       52                  0
# 8137  Insurance carriers and related activities       52                  0
# 8138  Insurance carriers and related activities       52                  0
# 8139                 Mining, except oil and gas       21                  0
# 8140                 Mining, except oil and gas       21                  1
# 8141                 Mining, except oil and gas       21                  0
# 8142                 Mining, except oil and gas       21                  0
# 8143                 Mining, except oil and gas       21                  0
# 8144                 Mining, except oil and gas       21                  0
# 8145                 Mining, except oil and gas       21                  0
# 8146                 Mining, except oil and gas       21                  0
# 8147                 Mining, except oil and gas       21                  0
# 8148                 Mining, except oil and gas       21                  0
# 8149                 Mining, except oil and gas       21                  0
# 8150                 Mining, except oil and gas       21                  0
# 8151                 Mining, except oil and gas       21                  0
# 8152                 Mining, except oil and gas       21                  0
# 8153                 Mining, except oil and gas       21                  0
# 8154                 Mining, except oil and gas       21                  0
# 8155                 Mining, except oil and gas       21                  0
# 8156                 Mining, except oil and gas       21                  0
# 8157                 Mining, except oil and gas       21                  0
# 8158                 Mining, except oil and gas       21                  0
#
# [8000 rows x 208 columns]

# %%
# output the final file
